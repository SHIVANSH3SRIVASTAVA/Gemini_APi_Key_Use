# %% [markdown]
# <a href="https://colab.research.google.com/github/SHIVANSH3SRIVASTAVA/Gemini_APi_Key_Use/blob/main/Gemini_API_Key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-genai

# %%
import google.generativeai as genai
from google.colab import userdata

KEY = userdata.get('GEMINI_API_KEY')
genai.configure(api_key=KEY)

model = genai.GenerativeModel("gemini-2.5-flash")
prompt = "Write a code in java for bubble sort and explain the code for a 10 year old"
response = model.generate_content(prompt)
print(response.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 2225.71ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 16179.51ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 2842.05ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 4470.18ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 14327.35ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 6403.46ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 1856.21ms
# ...

# %%
import google.generativeai as genai
from google.colab import userdata

KEY = userdata.get('Gemini_API_KEY')
genai.configure(api_key=KEY)

model = genai.GenerativeModel("gemini-2.5-flash")
prompt = "Write a html, css code for ecommerce website landing page for B.Tech final year student, also draft the project report"
response = model.generate_content(prompt)
print(response.text)
# Out:
# Okay, this is a fantastic project for a B.Tech final year student! It allows you to showcase your understanding of modern web development fundamentals (HTML5 semantics, CSS3 responsiveness, basic UI/UX principles).
#
# Let's create the code for an e-commerce landing page focused on "Tech Gadgets," and then draft a comprehensive project report.
#
# ---
#
# ## Part 1: HTML & CSS Code for E-commerce Landing Page
#
# This landing page will feature:
# 1.  **Header:** Logo, Navigation, Cart/Login icons.
# 2.  **Hero Section:** Catchy headline, CTA button, background image.
# 3.  **Feature Highlights:** Short blurbs about what makes the store great (e.g., quality, shipping).
# 4.  **Featured Products:** A grid display of example products.
# 5.  **Call to Action Banner:** Another prompt to explore more.
# 6.  **Footer:** Copyright, social media links.
#
# We'll use Google Fonts for typography and Font Awesome for icons.
#
# **File Structure:**
# ```
# ecommerce-landing-page/
# ...

# %%
import google.generativeai as genai
from google.colab import userdata

KEY = userdata.get('Gemini_API_KEY')
genai.configure(api_key=KEY)

model = genai.GenerativeModel("gemini-2.5-flash")
prompt = "Write a html, css code for ecommerce website landing page for enterprise client, also draft the project report"
response = model.generate_content(prompt)
print(response.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 34627.11ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 2502.89ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 59800.12ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 5871.23ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3033.94ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 6371.66ms
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 135420.92ms
# ...
