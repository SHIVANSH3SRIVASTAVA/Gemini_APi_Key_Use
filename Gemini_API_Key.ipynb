# %% [markdown]
# <a href="https://colab.research.google.com/github/SHIVANSH3SRIVASTAVA/Gemini_APi_Key_Use/blob/main/Gemini_API_Key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.12/dist-packages (1.54.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.12.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.14.1->google-genai) (2.43.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai) (0.6.1)

# %%
import google.generativeai as genai
from google.colab import userdata

KEY = userdata.get('GEMINI_API_KEY')
genai.configure(api_key=KEY)

model = genai.GenerativeModel("gemini-2.5-flash")
prompt = "Write a code in java for bubble sort and explain the code for a 10 year old"
response = model.generate_content(prompt)
print(response.text)
# Out:
# Okay, imagine you have a line of kids, and you want them to stand from shortest to tallest. But they're all mixed up! How would you make them sort themselves?
#
# Bubble Sort is a way a computer can do this, step by step, just like you might do it if you were trying to organize them.
#
# ---
#
# ## 🧍‍♀️🧍‍♂️ What is Bubble Sort? (The Kid Analogy)
#
# Imagine you have these kids, representing numbers:
# `[5, 1, 4, 2, 8]` (Their heights are 5 feet, 1 foot, 4 feet, etc.)
#
# Here's how Bubble Sort works, using our kid analogy:
#
# 1.  **Look at the first two kids:** Compare the first kid (5) with the second kid (1). Is the first kid taller than the second? Yes, 5 > 1.
# 2.  **Swap if taller:** If the first kid is taller, they switch places!
#     `[1, 5, 4, 2, 8]` (5 and 1 swapped)
# 3.  **Move to the next pair:** Now compare the *new* second kid (5) with the third kid (4). Is 5 > 4? Yes.
# 4.  **Swap again:** They switch!
#     `[1, 4, 5, 2, 8]` (5 and 4 swapped)
# 5.  **Keep going:** Compare the new third kid (5) with the fourth kid (2). Is 5 > 2? Yes.
# 6.  **Swap again:**
#     `[1, 4, 2, 5, 8]` (5 and 2 swapped)
# 7.  **Last pair:** Compare the new fourth kid (5) with the fifth kid (8). Is 5 > 8? No.
# 8.  **Don't swap:** They stay where they are.
#     `[1, 4, 2, 5, 8]`
#
# **End of the First Walk-Through:** Notice something cool? The tallest kid (8) has "bubbled up" all the way to the end! They are now in their correct spot.
#
# Now, we do this *again*, but we don't need to check the last kid because we know they're in the right spot. We repeat these "walk-throughs" until no more kids need to swap places. With each walk-through, another "tallest" kid bubbles to the end.
#
# That's why it's called **Bubble Sort** – the biggest numbers (or tallest kids) "bubble up" to their correct position at the end of the line, just like big bubbles rise to the top of a drink!
#
# ---
#
# ## 👩‍💻 The Java Code Explained for a 10-Year-Old
#
# Here's the code that does exactly what we just described with the kids:
#
# ```java
# public class BubbleSort {
#
#     // This is like a special instruction book for how to sort numbers.
#     // It's called 'bubbleSort' and it needs a list of numbers (an 'array' of 'int's)
#     public static void bubbleSort(int[] arr) {
#         int n = arr.length; // 'n' tells us how many numbers are in our list.
#
#         // This is the "Outer Loop" or "How many times do we need to walk through the line?"
#         // We walk through the line 'n-1' times because each time, one number gets to its correct place at the end.
#         for (int i = 0; i < n - 1; i++) {
#
#             // This is the "Inner Loop" or "Walking along the line, comparing pairs of kids."
#             // 'j' helps us look at each pair. We stop 'i' steps earlier because the last 'i' numbers are already sorted.
#             for (int j = 0; j < n - 1 - i; j++) {
#
#                 // This is the "Are you taller than the person next to you on your right?" check.
#                 // 'arr[j]' is the current number, 'arr[j+1]' is the next number.
#                 if (arr[j] > arr[j + 1]) {
#
#                     // If 'yes' (the current number is bigger), then we need to swap them!
#                     // 'temp' is like a temporary holding spot for one kid while they switch.
#                     int temp = arr[j];       // 1. Put the first kid (arr[j]) into the holding spot (temp).
#                     arr[j] = arr[j + 1];     // 2. Move the second kid (arr[j+1]) into the first kid's spot.
#                     arr[j + 1] = temp;       // 3. Move the kid from the holding spot (temp) into the second kid's spot.
#                 }
#             }
#         }
#     }
#
#     // This is a special helper that just prints out all the numbers in our list.
#     // It helps us see what the list looks like before and after sorting.
#     public static void printArray(int[] arr) {
#         for (int i = 0; i < arr.length; i++) {
#             System.out.print(arr[i] + " "); // Print each number with a space after it.
#         }
#         System.out.println(); // Go to the next line after printing all numbers.
#     }
#
#     // This is the main part of our program, like the "start button."
#     public static void main(String[] args) {
#         // Here's our messy line of numbers (kids)!
#         int[] numbers = {64, 34, 25, 12, 22, 11, 90};
#
#         System.out.println("Original line of kids (numbers):");
#         printArray(numbers); // Show what the numbers look like *before* sorting.
#
#         bubbleSort(numbers); // Tell our special 'bubbleSort' instruction book to sort these 'numbers'.
#
#         System.out.println("Sorted line of kids (numbers):");
#         printArray(numbers); // Show what the numbers look like *after* sorting.
#     }
# }
# ```
#
# ---
#
# ### How to Run This Code (If you have Java installed)
#
# 1.  **Save it:** Open a text editor (like Notepad on Windows, TextEdit on Mac, or a code editor like VS Code) and paste the code. Save it as `BubbleSort.java`. Make sure the file name is exactly `BubbleSort.java`.
# 2.  **Open Terminal/Command Prompt:** Find your computer's terminal or command prompt.
# 3.  **Navigate to the folder:** Use the `cd` command to go to the folder where you saved `BubbleSort.java`. For example, `cd C:\Users\YourName\Documents`
# 4.  **Compile:** Type `javac BubbleSort.java` and press Enter. This translates the code into something the computer understands. If there are no errors, it will create a `BubbleSort.class` file.
# 5.  **Run:** Type `java BubbleSort` and press Enter.
#
# You will see output like this:
#
# ```
# Original line of kids (numbers):
# 64 34 25 12 22 11 90
# Sorted line of kids (numbers):
# 11 12 22 25 34 64 90
# ```
#
# Voila! The computer successfully sorted the numbers from smallest to largest, just like bubble sort made the kids line up from shortest to tallest!
